# %%
#Rock, Paper, Scissors
import random

#For replay 
while True: 
    
    print("The rules of the Rock paper scissor game are as follows: \n"
                                    +"Rock vs Paper-> Paper wins \n"
                                    + "Rock vs Scissor-> Rock wins \n"
                                    +"Paper vs Scissor-> Scissor wins \n")

    Options= ["R", "P","S"]

    print("Enter a choice for the round: \"R\" for Rock, \"P\" for Paper and \"S\" for Scissor \n")
    
    #Take in user input
    while True: 
        
        user_choice = str(input("User turn: "))

        if user_choice == "R":
            u_action = "Rock"
            break
        elif user_choice == "P":
            u_action = "Paper"
            break
        elif user_choice == "S":
            u_action = "Scissors"
            break
        else:
            print("Invalid input!")
            
    #Computer input
    computer_choice = random.choice(Options)
    if computer_choice == "R":
        c_action = "Rock"
    elif computer_choice == "P":
        c_action = "Paper"
    elif computer_choice == "S":
        c_action = "Scissors"
        
    print(f"\nYou chose the {u_action}, and the computer chose the {c_action}.\n")

    #Comparisms
    if user_choice == computer_choice:
        print(f"You both selected {action}. It's a tie!")

    elif user_choice == "R":
        if computer_choice == "P":
            print("Paper covers up the rock. You lose.")
        else:
            print("Rock gets smashed by scissors. You win!")

    elif user_choice == "P":
        if computer_choice == "S":
            print("Scissors cuts paper. You lose.")
        else:
            print("Paper covers rock. You win!")

    elif user_choice == "S":
        if computer_choice == "R":
            print("Rock smashes scissors. You lose.")
        else:
            print("Scissors cuts paper. You win!")

    #Replay?
    print("Do you want to play again? (Y/N)")
    replay = input()
    if replay.lower() != "y":
        print("\nThank you for playing")
        break
